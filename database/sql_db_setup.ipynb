# %%
import pandas as pd

import sqlalchemy
from sqlalchemy import create_engine, Column, Integer, Float, String, ForeignKey
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import relationship, sessionmaker


from sqlalchemy.orm import configure_mappers
from sqlalchemy_schemadisplay import create_schema_graph
from sqlalchemy import MetaData

# %% [markdown]
# # Define the SQLAlchemy Database Model
#
# ## Proposed Schema
# - **Property** (Core property information). Stores details specific to each property.
# - **Location** (Details about the property location). Stores information such as country and other geographic details.
# - **Price** (Price data for each property). Stores pricing information.
# - **Feature** (Features such as average rooms, age, occupancy). Stores characteristics of the property such as median income in the area, number of rooms, etc.

# %%
# Define the database URL
DATABASE_URL = "sqlite:///real_estate.db"

# Create an engine
engine = create_engine(DATABASE_URL, echo=True)

# Define a base class for the declarative model
Base = declarative_base()
# Out:
# /var/folders/t_/k5bhrc1x419crrfg_t8zp5nm0000gp/T/ipykernel_47081/4272391801.py:8: MovedIn20Warning: The ``declarative_base()`` function is now available as sqlalchemy.orm.declarative_base(). (deprecated since: 2.0) (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   Base = declarative_base()

# %% [markdown]
# ### Property

# %%
# Property Table: Holds core property information
class Property(Base):
    __tablename__ = 'property'

    property_id = Column(Integer, primary_key=True, autoincrement=True)
    location_id = Column(Integer, ForeignKey('location.location_id'))
    feature_id = Column(Integer, ForeignKey('feature.feature_id'))
    price_id = Column(Integer, ForeignKey('price.price_id'))

    # Relationships
    location = relationship("Location", back_populates="properties")
    feature = relationship("Feature", back_populates="properties")
    price = relationship("Price", back_populates="properties")

# %% [markdown]
# ### Location

# %%
# Location Table: Stores location details
class Location(Base):
    __tablename__ = 'location'

    location_id = Column(Integer, primary_key=True, autoincrement=True)
    country = Column(String, nullable=False)

    # Relationship to Property
    properties = relationship("Property", back_populates="location")

# %% [markdown]
# ### Price

# %%
# Price Table: Stores price information
class Price(Base):
    __tablename__ = 'price'

    price_id = Column(Integer, primary_key=True, autoincrement=True)
    price = Column(Float, nullable=False)

    # Relationship to Property
    properties = relationship("Property", back_populates="price")

# %% [markdown]
# ### Feature

# %%
class Feature(Base):
    __tablename__ = 'feature'

    feature_id = Column(Integer, primary_key=True, autoincrement=True)
    med_income = Column(Float, nullable=False)
    house_age = Column(Float, nullable=False)
    ave_rooms = Column(Float, nullable=False)
    ave_bedrooms = Column(Float, nullable=False)
    ave_occupancy = Column(Float, nullable=False)

    # Relationship to Property
    properties = relationship("Property", back_populates="feature")

# %% [markdown]
# ## Finishing the DB setup

# %%
# Create the tables in the database
Base.metadata.create_all(engine)

# Create a session to interact with the database
Session = sessionmaker(bind=engine)
session = Session()
# Out:
# 2024-10-17 14:36:51,020 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 14:36:51,022 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("property")
# 2024-10-17 14:36:51,024 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-10-17 14:36:51,025 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("property")
# 2024-10-17 14:36:51,026 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-10-17 14:36:51,027 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("location")
# 2024-10-17 14:36:51,028 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-10-17 14:36:51,029 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("location")
# 2024-10-17 14:36:51,030 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-10-17 14:36:51,031 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("price")
# 2024-10-17 14:36:51,032 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-10-17 14:36:51,033 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("price")
# 2024-10-17 14:36:51,033 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-10-17 14:36:51,034 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("feature")
# 2024-10-17 14:36:51,035 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-10-17 14:36:51,036 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("feature")
# 2024-10-17 14:36:51,037 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-10-17 14:36:51,039 INFO sqlalchemy.engine.Engine
# CREATE TABLE location (
# 	location_id INTEGER NOT NULL,
# 	country VARCHAR NOT NULL,
# 	PRIMARY KEY (location_id)
# )
#
#
# 2024-10-17 14:36:51,040 INFO sqlalchemy.engine.Engine [no key 0.00096s] ()
# 2024-10-17 14:36:51,044 INFO sqlalchemy.engine.Engine
# CREATE TABLE price (
# 	price_id INTEGER NOT NULL,
# 	price FLOAT NOT NULL,
# 	PRIMARY KEY (price_id)
# )
#
#
# 2024-10-17 14:36:51,044 INFO sqlalchemy.engine.Engine [no key 0.00063s] ()
# 2024-10-17 14:36:51,047 INFO sqlalchemy.engine.Engine
# CREATE TABLE feature (
# 	feature_id INTEGER NOT NULL,
# 	med_income FLOAT NOT NULL,
# 	house_age FLOAT NOT NULL,
# 	ave_rooms FLOAT NOT NULL,
# 	ave_bedrooms FLOAT NOT NULL,
# 	ave_occupancy FLOAT NOT NULL,
# 	PRIMARY KEY (feature_id)
# )
#
#
# 2024-10-17 14:36:51,047 INFO sqlalchemy.engine.Engine [no key 0.00044s] ()
# 2024-10-17 14:36:51,049 INFO sqlalchemy.engine.Engine
# CREATE TABLE property (
# 	property_id INTEGER NOT NULL,
# 	location_id INTEGER,
# 	feature_id INTEGER,
# 	price_id INTEGER,
# 	PRIMARY KEY (property_id),
# 	FOREIGN KEY(location_id) REFERENCES location (location_id),
# 	FOREIGN KEY(feature_id) REFERENCES feature (feature_id),
# 	FOREIGN KEY(price_id) REFERENCES price (price_id)
# )
#
#
# 2024-10-17 14:36:51,050 INFO sqlalchemy.engine.Engine [no key 0.00058s] ()
# 2024-10-17 14:36:51,052 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ## Create the ERD diagram

# %%
# Create engine
engine = create_engine("sqlite:///real_estate.db")

# Define metadata and reflect from engine
metadata = MetaData()
metadata.reflect(bind=engine)

# Configure mappers if using SQLAlchemy ORM
configure_mappers()

# Step 4: Create schema graph (add engine argument)
graph = create_schema_graph(
    metadata=metadata,
    engine=engine,
    show_datatypes=True,  # Show data types in the diagram
    show_indexes=True,  # Show index information in the diagram
    rankdir="LR",  # Layout from left to right
    concentrate=False  # No edge concentration
)

# Save the ER diagram to a file
graph.write_png("real_estate_schema.png")

# %% [markdown]
# ## Insert Data into the New Tables

# %%
# Load the dataset
df = pd.read_csv('../data/clean/combined_dataset.csv')

# %%
# Dictionaries to store IDs for Location, Feature, and Price entries to avoid redundancy
location_map = {}
feature_map = {}
price_map = {}

# %%
# Insert data into the new tables
properties = []
for index, row in df.iterrows():
    # Insert Location
    country = row['Country']
    if country not in location_map:
        location_entry = Location(country=country)
        session.add(location_entry)
        session.commit()
        location_map[country] = location_entry.location_id
    location_id = location_map[country]

    # Insert Feature
    feature_key = (row['MedInc'], row['HouseAge'], row['AveRooms'], row['AveBedrms'], row['AveOccup'])
    if feature_key not in feature_map:
        feature_entry = Feature(
            med_income=row['MedInc'],
            house_age=row['HouseAge'],
            ave_rooms=row['AveRooms'],
            ave_bedrooms=row['AveBedrms'],
            ave_occupancy=row['AveOccup']
        )
        session.add(feature_entry)
        session.commit()
        feature_map[feature_key] = feature_entry.feature_id
    feature_id = feature_map[feature_key]

    # Insert Price
    price = row['Price']
    if price not in price_map:
        price_entry = Price(price=price)
        session.add(price_entry)
        session.commit()
        price_map[price] = price_entry.price_id
    price_id = price_map[price]

    # Create Property entry
    property_entry = Property(
        location_id=location_id,
        feature_id=feature_id,
        price_id=price_id
    )
    properties.append(property_entry)
    
print("Data has been successfully inserted into the normalized database.")
# Out:
# 2024-10-17 12:43:30,741 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:30,743 INFO sqlalchemy.engine.Engine INSERT INTO location (country) VALUES (?)
# 2024-10-17 12:43:30,744 INFO sqlalchemy.engine.Engine [generated in 0.00113s] ('Slovakia',)
# 2024-10-17 12:43:30,746 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:30,749 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:30,752 INFO sqlalchemy.engine.Engine SELECT location.location_id AS location_location_id, location.country AS location_country
# FROM location
# WHERE location.location_id = ?
# 2024-10-17 12:43:30,753 INFO sqlalchemy.engine.Engine [generated in 0.00108s] (3,)
# 2024-10-17 12:43:30,756 INFO sqlalchemy.engine.Engine INSERT INTO feature (med_income, house_age, ave_rooms, ave_bedrooms, ave_occupancy) VALUES (?, ?, ?, ?, ?)
# 2024-10-17 12:43:30,756 INFO sqlalchemy.engine.Engine [generated in 0.00073s] (2.5634, 24.0, 3.0, 3.0, 3.6)
# 2024-10-17 12:43:30,758 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:30,760 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:30,762 INFO sqlalchemy.engine.Engine SELECT feature.feature_id AS feature_feature_id, feature.med_income AS feature_med_income, feature.house_age AS feature_house_age, feature.ave_rooms AS feature_ave_rooms, feature.ave_bedrooms AS feature_ave_bedrooms, feature.ave_occupancy AS feature_ave_occupancy
# FROM feature
# WHERE feature.feature_id = ?
# 2024-10-17 12:43:30,762 INFO sqlalchemy.engine.Engine [generated in 0.00071s] (17023,)
# 2024-10-17 12:43:30,764 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:30,765 INFO sqlalchemy.engine.Engine [generated in 0.00055s] (45780.0,)
# 2024-10-17 12:43:30,766 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:30,769 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:30,770 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:30,771 INFO sqlalchemy.engine.Engine [generated in 0.00069s] (6221,)
# 2024-10-17 12:43:30,773 INFO sqlalchemy.engine.Engine INSERT INTO feature (med_income, house_age, ave_rooms, ave_bedrooms, ave_occupancy) VALUES (?, ?, ?, ?, ?)
# 2024-10-17 12:43:30,774 INFO sqlalchemy.engine.Engine [cached since 0.01827s ago] (3.5348, 24.0, 1.0, 1.0, 1.2)
# 2024-10-17 12:43:30,776 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:30,783 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:30,784 INFO sqlalchemy.engine.Engine SELECT feature.feature_id AS feature_feature_id, feature.med_income AS feature_med_income, feature.house_age AS feature_house_age, feature.ave_rooms AS feature_ave_rooms, feature.ave_bedrooms AS feature_ave_bedrooms, feature.ave_occupancy AS feature_ave_occupancy
# FROM feature
# WHERE feature.feature_id = ?
# 2024-10-17 12:43:30,784 INFO sqlalchemy.engine.Engine [cached since 0.02272s ago] (17024,)
# 2024-10-17 12:43:30,786 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:30,793 INFO sqlalchemy.engine.Engine [cached since 0.0288s ago] (116630.0,)
# 2024-10-17 12:43:30,796 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:30,811 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:30,812 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:30,824 INFO sqlalchemy.engine.Engine [cached since 0.054s ago] (6222,)
# 2024-10-17 12:43:30,827 INFO sqlalchemy.engine.Engine INSERT INTO feature (med_income, house_age, ave_rooms, ave_bedrooms, ave_occupancy) VALUES (?, ?, ?, ?, ?)
# 2024-10-17 12:43:30,831 INFO sqlalchemy.engine.Engine [cached since 0.07532s ago] (3.5348, 24.0, 3.0, 3.0, 3.6)
# 2024-10-17 12:43:30,833 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:30,836 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:30,837 INFO sqlalchemy.engine.Engine SELECT feature.feature_id AS feature_feature_id, feature.med_income AS feature_med_income, feature.house_age AS feature_house_age, feature.ave_rooms AS feature_ave_rooms, feature.ave_bedrooms AS feature_ave_bedrooms, feature.ave_occupancy AS feature_ave_occupancy
# FROM feature
# WHERE feature.feature_id = ?
# 2024-10-17 12:43:30,838 INFO sqlalchemy.engine.Engine [cached since 0.07655s ago] (17025,)
# 2024-10-17 12:43:30,840 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:30,841 INFO sqlalchemy.engine.Engine [cached since 0.07716s ago] (114450.0,)
# 2024-10-17 12:43:30,843 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:30,845 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:30,846 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:30,846 INFO sqlalchemy.engine.Engine [cached since 0.07604s ago] (6223,)
# 2024-10-17 12:43:30,847 INFO sqlalchemy.engine.Engine INSERT INTO feature (med_income, house_age, ave_rooms, ave_bedrooms, ave_occupancy) VALUES (?, ?, ?, ?, ?)
# 2024-10-17 12:43:30,848 INFO sqlalchemy.engine.Engine [cached since 0.09233s ago] (2.5634, 6.0, 2.0, 2.0, 2.4)
# 2024-10-17 12:43:30,849 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:30,852 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:30,853 INFO sqlalchemy.engine.Engine SELECT feature.feature_id AS feature_feature_id, feature.med_income AS feature_med_income, feature.house_age AS feature_house_age, feature.ave_rooms AS feature_ave_rooms, feature.ave_bedrooms AS feature_ave_bedrooms, feature.ave_occupancy AS feature_ave_occupancy
# FROM feature
# WHERE feature.feature_id = ?
# 2024-10-17 12:43:30,854 INFO sqlalchemy.engine.Engine [cached since 0.09251s ago] (17026,)
# 2024-10-17 12:43:30,856 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:30,857 INFO sqlalchemy.engine.Engine [cached since 0.09254s ago] (89380.0,)
# 2024-10-17 12:43:30,858 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:30,861 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:30,861 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:30,862 INFO sqlalchemy.engine.Engine [cached since 0.09168s ago] (6224,)
# 2024-10-17 12:43:30,864 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:30,864 INFO sqlalchemy.engine.Engine [cached since 0.09977s ago] (111180.0,)
# 2024-10-17 12:43:30,865 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:30,868 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:30,870 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:30,871 INFO sqlalchemy.engine.Engine [cached since 0.1004s ago] (6225,)
# 2024-10-17 12:43:30,872 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:30,873 INFO sqlalchemy.engine.Engine [cached since 0.1089s ago] (140610.0,)
# 2024-10-17 12:43:30,874 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:30,877 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:30,878 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:30,878 INFO sqlalchemy.engine.Engine [cached since 0.108s ago] (6226,)
# 2024-10-17 12:43:30,880 INFO sqlalchemy.engine.Engine INSERT INTO feature (med_income, house_age, ave_rooms, ave_bedrooms, ave_occupancy) VALUES (?, ?, ?, ?, ?)
# 2024-10-17 12:43:30,881 INFO sqlalchemy.engine.Engine [cached since 0.1253s ago] (2.5634, 24.0, 2.0, 2.0, 2.4)
# 2024-10-17 12:43:30,882 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:30,886 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:30,888 INFO sqlalchemy.engine.Engine SELECT feature.feature_id AS feature_feature_id, feature.med_income AS feature_med_income, feature.house_age AS feature_house_age, feature.ave_rooms AS feature_ave_rooms, feature.ave_bedrooms AS feature_ave_bedrooms, feature.ave_occupancy AS feature_ave_occupancy
# FROM feature
# WHERE feature.feature_id = ?
# 2024-10-17 12:43:30,888 INFO sqlalchemy.engine.Engine [cached since 0.1264s ago] (17027,)
# 2024-10-17 12:43:30,890 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:30,890 INFO sqlalchemy.engine.Engine [cached since 0.126s ago] (103550.0,)
# 2024-10-17 12:43:30,891 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:30,894 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:30,894 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:30,895 INFO sqlalchemy.engine.Engine [cached since 0.1244s ago] (6227,)
# 2024-10-17 12:43:30,896 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:30,897 INFO sqlalchemy.engine.Engine [cached since 0.1325s ago] (81641.0,)
# 2024-10-17 12:43:30,898 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:30,900 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:30,901 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:30,901 INFO sqlalchemy.engine.Engine [cached since 0.1307s ago] (6228,)
# 2024-10-17 12:43:30,902 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:30,903 INFO sqlalchemy.engine.Engine [cached since 0.1386s ago] (70741.0,)
# 2024-10-17 12:43:30,904 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:30,907 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:30,908 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:30,908 INFO sqlalchemy.engine.Engine [cached since 0.1382s ago] (6229,)
# 2024-10-17 12:43:30,912 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:30,912 INFO sqlalchemy.engine.Engine [cached since 0.1481s ago] (90470.0,)
# 2024-10-17 12:43:30,914 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:30,916 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:30,916 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:30,917 INFO sqlalchemy.engine.Engine [cached since 0.1465s ago] (6230,)
# 2024-10-17 12:43:30,918 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:30,919 INFO sqlalchemy.engine.Engine [cached since 0.1546s ago] (105185.0,)
# 2024-10-17 12:43:30,920 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:30,922 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:30,923 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:30,923 INFO sqlalchemy.engine.Engine [cached since 0.1531s ago] (6231,)
# 2024-10-17 12:43:30,925 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:30,925 INFO sqlalchemy.engine.Engine [cached since 0.1609s ago] (90361.0,)
# 2024-10-17 12:43:30,926 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:30,928 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:30,929 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:30,930 INFO sqlalchemy.engine.Engine [cached since 0.1595s ago] (6232,)
# 2024-10-17 12:43:30,931 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:30,932 INFO sqlalchemy.engine.Engine [cached since 0.1673s ago] (73030.0,)
# 2024-10-17 12:43:30,933 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:30,935 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:30,936 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:30,936 INFO sqlalchemy.engine.Engine [cached since 0.1656s ago] (6233,)
# 2024-10-17 12:43:30,937 INFO sqlalchemy.engine.Engine INSERT INTO feature (med_income, house_age, ave_rooms, ave_bedrooms, ave_occupancy) VALUES (?, ?, ?, ?, ?)
# 2024-10-17 12:43:30,938 INFO sqlalchemy.engine.Engine [cached since 0.182s ago] (2.5634, 24.0, 1.0, 1.0, 1.2)
# 2024-10-17 12:43:30,939 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:30,941 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:30,941 INFO sqlalchemy.engine.Engine SELECT feature.feature_id AS feature_feature_id, feature.med_income AS feature_med_income, feature.house_age AS feature_house_age, feature.ave_rooms AS feature_ave_rooms, feature.ave_bedrooms AS feature_ave_bedrooms, feature.ave_occupancy AS feature_ave_occupancy
# FROM feature
# WHERE feature.feature_id = ?
# 2024-10-17 12:43:30,942 INFO sqlalchemy.engine.Engine [cached since 0.1803s ago] (17028,)
# 2024-10-17 12:43:30,943 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:30,944 INFO sqlalchemy.engine.Engine [cached since 0.1794s ago] (52320.00000000001,)
# 2024-10-17 12:43:30,945 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:30,947 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:30,948 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:30,948 INFO sqlalchemy.engine.Engine [cached since 0.1779s ago] (6234,)
# 2024-10-17 12:43:30,950 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:30,951 INFO sqlalchemy.engine.Engine [cached since 0.1865s ago] (87091.0,)
# 2024-10-17 12:43:30,952 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:30,954 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:30,955 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:30,955 INFO sqlalchemy.engine.Engine [cached since 0.1848s ago] (6235,)
# 2024-10-17 12:43:30,957 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:30,957 INFO sqlalchemy.engine.Engine [cached since 0.1929s ago] (71395.0,)
# 2024-10-17 12:43:30,958 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:30,960 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:30,962 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:30,964 INFO sqlalchemy.engine.Engine [cached since 0.1933s ago] (6236,)
# 2024-10-17 12:43:30,965 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:30,966 INFO sqlalchemy.engine.Engine [cached since 0.2015s ago] (118810.0,)
# 2024-10-17 12:43:30,968 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:30,970 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:30,971 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:30,971 INFO sqlalchemy.engine.Engine [cached since 0.2012s ago] (6237,)
# 2024-10-17 12:43:30,973 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:30,974 INFO sqlalchemy.engine.Engine [cached since 0.2099s ago] (74120.0,)
# 2024-10-17 12:43:30,975 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:30,980 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:30,981 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:30,982 INFO sqlalchemy.engine.Engine [cached since 0.2113s ago] (6238,)
# 2024-10-17 12:43:30,984 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:30,986 INFO sqlalchemy.engine.Engine [cached since 0.2218s ago] (102460.0,)
# 2024-10-17 12:43:30,988 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:30,991 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:30,992 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:30,992 INFO sqlalchemy.engine.Engine [cached since 0.2221s ago] (6239,)
# 2024-10-17 12:43:30,994 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:30,994 INFO sqlalchemy.engine.Engine [cached since 0.2299s ago] (81739.1,)
# 2024-10-17 12:43:30,995 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:30,998 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:30,998 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:30,999 INFO sqlalchemy.engine.Engine [cached since 0.2285s ago] (6240,)
# 2024-10-17 12:43:31,000 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:31,001 INFO sqlalchemy.engine.Engine [cached since 0.2365s ago] (96465.0,)
# 2024-10-17 12:43:31,002 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:31,005 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:31,006 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:31,006 INFO sqlalchemy.engine.Engine [cached since 0.2358s ago] (6241,)
# 2024-10-17 12:43:31,008 INFO sqlalchemy.engine.Engine INSERT INTO feature (med_income, house_age, ave_rooms, ave_bedrooms, ave_occupancy) VALUES (?, ?, ?, ?, ?)
# 2024-10-17 12:43:31,009 INFO sqlalchemy.engine.Engine [cached since 0.2533s ago] (2.5634, 24.0, 4.0, 4.0, 4.8)
# 2024-10-17 12:43:31,010 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:31,012 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:31,013 INFO sqlalchemy.engine.Engine SELECT feature.feature_id AS feature_feature_id, feature.med_income AS feature_med_income, feature.house_age AS feature_house_age, feature.ave_rooms AS feature_ave_rooms, feature.ave_bedrooms AS feature_ave_bedrooms, feature.ave_occupancy AS feature_ave_occupancy
# FROM feature
# WHERE feature.feature_id = ?
# 2024-10-17 12:43:31,014 INFO sqlalchemy.engine.Engine [cached since 0.252s ago] (17029,)
# 2024-10-17 12:43:31,015 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:31,015 INFO sqlalchemy.engine.Engine [cached since 0.2508s ago] (100825.0,)
# 2024-10-17 12:43:31,016 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:31,019 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:31,021 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:31,021 INFO sqlalchemy.engine.Engine [cached since 0.251s ago] (6242,)
# 2024-10-17 12:43:31,023 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:31,023 INFO sqlalchemy.engine.Engine [cached since 0.2589s ago] (92650.0,)
# 2024-10-17 12:43:31,025 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:31,027 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:31,028 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:31,028 INFO sqlalchemy.engine.Engine [cached since 0.2578s ago] (6243,)
# 2024-10-17 12:43:31,030 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:31,030 INFO sqlalchemy.engine.Engine [cached since 0.2659s ago] (98600.31,)
# 2024-10-17 12:43:31,031 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:31,033 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:31,034 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:31,034 INFO sqlalchemy.engine.Engine [cached since 0.2641s ago] (6244,)
# 2024-10-17 12:43:31,036 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:31,036 INFO sqlalchemy.engine.Engine [cached since 0.2719s ago] (89271.0,)
# 2024-10-17 12:43:31,037 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:31,039 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:31,040 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:31,041 INFO sqlalchemy.engine.Engine [cached since 0.2703s ago] (6245,)
# 2024-10-17 12:43:31,042 INFO sqlalchemy.engine.Engine INSERT INTO feature (med_income, house_age, ave_rooms, ave_bedrooms, ave_occupancy) VALUES (?, ?, ?, ?, ?)
# 2024-10-17 12:43:31,043 INFO sqlalchemy.engine.Engine [cached since 0.2872s ago] (3.5348, 24.0, 4.0, 4.0, 4.8)
# 2024-10-17 12:43:31,044 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:31,046 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:31,047 INFO sqlalchemy.engine.Engine SELECT feature.feature_id AS feature_feature_id, feature.med_income AS feature_med_income, feature.house_age AS feature_house_age, feature.ave_rooms AS feature_ave_rooms, feature.ave_bedrooms AS feature_ave_bedrooms, feature.ave_occupancy AS feature_ave_occupancy
# FROM feature
# WHERE feature.feature_id = ?
# 2024-10-17 12:43:31,048 INFO sqlalchemy.engine.Engine [cached since 0.2861s ago] (17030,)
# 2024-10-17 12:43:31,049 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:31,050 INFO sqlalchemy.engine.Engine [cached since 0.2859s ago] (123170.0,)
# 2024-10-17 12:43:31,051 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:31,053 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:31,054 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:31,055 INFO sqlalchemy.engine.Engine [cached since 0.2844s ago] (6246,)
# 2024-10-17 12:43:31,056 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:31,057 INFO sqlalchemy.engine.Engine [cached since 0.2922s ago] (65182.00000000001,)
# 2024-10-17 12:43:31,058 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:31,060 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:31,060 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:31,061 INFO sqlalchemy.engine.Engine [cached since 0.2904s ago] (6247,)
# 2024-10-17 12:43:31,062 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:31,063 INFO sqlalchemy.engine.Engine [cached since 0.2986s ago] (100280.0,)
# 2024-10-17 12:43:31,064 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:31,066 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:31,067 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:31,067 INFO sqlalchemy.engine.Engine [cached since 0.2972s ago] (6248,)
# 2024-10-17 12:43:31,071 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:31,072 INFO sqlalchemy.engine.Engine [cached since 0.3076s ago] (91560.0,)
# 2024-10-17 12:43:31,073 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:31,075 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:31,076 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:31,076 INFO sqlalchemy.engine.Engine [cached since 0.3059s ago] (6249,)
# 2024-10-17 12:43:31,078 INFO sqlalchemy.engine.Engine INSERT INTO feature (med_income, house_age, ave_rooms, ave_bedrooms, ave_occupancy) VALUES (?, ?, ?, ?, ?)
# 2024-10-17 12:43:31,078 INFO sqlalchemy.engine.Engine [cached since 0.3226s ago] (4.74325, 24.0, 4.0, 4.0, 4.8)
# 2024-10-17 12:43:31,079 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:31,082 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:31,082 INFO sqlalchemy.engine.Engine SELECT feature.feature_id AS feature_feature_id, feature.med_income AS feature_med_income, feature.house_age AS feature_house_age, feature.ave_rooms AS feature_ave_rooms, feature.ave_bedrooms AS feature_ave_bedrooms, feature.ave_occupancy AS feature_ave_occupancy
# FROM feature
# WHERE feature.feature_id = ?
# 2024-10-17 12:43:31,083 INFO sqlalchemy.engine.Engine [cached since 0.3211s ago] (17031,)
# 2024-10-17 12:43:31,084 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:31,085 INFO sqlalchemy.engine.Engine [cached since 0.3205s ago] (151510.0,)
# 2024-10-17 12:43:31,086 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:31,088 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:31,089 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:31,090 INFO sqlalchemy.engine.Engine [cached since 0.3197s ago] (6250,)
# 2024-10-17 12:43:31,092 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:31,093 INFO sqlalchemy.engine.Engine [cached since 0.3287s ago] (125350.0,)
# 2024-10-17 12:43:31,095 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:31,098 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:31,098 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:31,099 INFO sqlalchemy.engine.Engine [cached since 0.3286s ago] (6251,)
# 2024-10-17 12:43:31,100 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:31,101 INFO sqlalchemy.engine.Engine [cached since 0.3362s ago] (81750.0,)
# 2024-10-17 12:43:31,102 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:31,104 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:31,105 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:31,105 INFO sqlalchemy.engine.Engine [cached since 0.3351s ago] (6252,)
# 2024-10-17 12:43:31,108 INFO sqlalchemy.engine.Engine INSERT INTO feature (med_income, house_age, ave_rooms, ave_bedrooms, ave_occupancy) VALUES (?, ?, ?, ?, ?)
# 2024-10-17 12:43:31,109 INFO sqlalchemy.engine.Engine [cached since 0.3532s ago] (4.74325, 24.0, 3.0, 3.0, 3.6)
# 2024-10-17 12:43:31,111 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:31,113 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:31,114 INFO sqlalchemy.engine.Engine SELECT feature.feature_id AS feature_feature_id, feature.med_income AS feature_med_income, feature.house_age AS feature_house_age, feature.ave_rooms AS feature_ave_rooms, feature.ave_bedrooms AS feature_ave_bedrooms, feature.ave_occupancy AS feature_ave_occupancy
# FROM feature
# WHERE feature.feature_id = ?
# 2024-10-17 12:43:31,114 INFO sqlalchemy.engine.Engine [cached since 0.3523s ago] (17032,)
# 2024-10-17 12:43:31,115 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:31,115 INFO sqlalchemy.engine.Engine [cached since 0.3512s ago] (150420.0,)
# 2024-10-17 12:43:31,116 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:31,119 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:31,119 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:31,120 INFO sqlalchemy.engine.Engine [cached since 0.3497s ago] (6253,)
# 2024-10-17 12:43:31,122 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:31,123 INFO sqlalchemy.engine.Engine [cached since 0.3586s ago] (130800.0,)
# 2024-10-17 12:43:31,124 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:31,126 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:31,127 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:31,127 INFO sqlalchemy.engine.Engine [cached since 0.3571s ago] (6254,)
# 2024-10-17 12:43:31,129 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:31,130 INFO sqlalchemy.engine.Engine [cached since 0.3653s ago] (79570.0,)
# 2024-10-17 12:43:31,131 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:31,134 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:31,135 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:31,135 INFO sqlalchemy.engine.Engine [cached since 0.365s ago] (6255,)
# 2024-10-17 12:43:31,137 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:31,137 INFO sqlalchemy.engine.Engine [cached since 0.3728s ago] (106820.0,)
# 2024-10-17 12:43:31,138 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:31,140 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:31,141 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:31,141 INFO sqlalchemy.engine.Engine [cached since 0.3709s ago] (6256,)
# 2024-10-17 12:43:31,142 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:31,143 INFO sqlalchemy.engine.Engine [cached since 0.3787s ago] (85020.0,)
# 2024-10-17 12:43:31,144 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:31,146 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:31,147 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:31,147 INFO sqlalchemy.engine.Engine [cached since 0.3771s ago] (6257,)
# 2024-10-17 12:43:31,149 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:31,150 INFO sqlalchemy.engine.Engine [cached since 0.3853s ago] (104640.0,)
# 2024-10-17 12:43:31,151 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:31,153 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:31,154 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:31,154 INFO sqlalchemy.engine.Engine [cached since 0.3838s ago] (6258,)
# 2024-10-17 12:43:31,156 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:31,156 INFO sqlalchemy.engine.Engine [cached since 0.3919s ago] (101370.0,)
# 2024-10-17 12:43:31,157 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:31,160 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:31,160 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:31,161 INFO sqlalchemy.engine.Engine [cached since 0.3909s ago] (6259,)
# 2024-10-17 12:43:31,163 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:31,164 INFO sqlalchemy.engine.Engine [cached since 0.3995s ago] (76191.0,)
# 2024-10-17 12:43:31,165 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:31,167 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:31,168 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:31,168 INFO sqlalchemy.engine.Engine [cached since 0.3982s ago] (6260,)
# 2024-10-17 12:43:31,170 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:31,171 INFO sqlalchemy.engine.Engine [cached since 0.4067s ago] (72385.81000000001,)
# 2024-10-17 12:43:31,172 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:31,174 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:31,175 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:31,176 INFO sqlalchemy.engine.Engine [cached since 0.4055s ago] (6261,)
# 2024-10-17 12:43:31,177 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:31,178 INFO sqlalchemy.engine.Engine [cached since 0.4135s ago] (71940.0,)
# 2024-10-17 12:43:31,179 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:31,181 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:31,182 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:31,182 INFO sqlalchemy.engine.Engine [cached since 0.4121s ago] (6262,)
# 2024-10-17 12:43:31,184 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:31,185 INFO sqlalchemy.engine.Engine [cached since 0.4203s ago] (105730.0,)
# 2024-10-17 12:43:31,188 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:31,190 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:31,191 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:31,191 INFO sqlalchemy.engine.Engine [cached since 0.4212s ago] (6263,)
# 2024-10-17 12:43:31,193 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:31,194 INFO sqlalchemy.engine.Engine [cached since 0.4294s ago] (75101.0,)
# 2024-10-17 12:43:31,195 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:31,198 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:31,198 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:31,199 INFO sqlalchemy.engine.Engine [cached since 0.4284s ago] (6264,)
# 2024-10-17 12:43:31,200 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:31,200 INFO sqlalchemy.engine.Engine [cached since 0.4361s ago] (94819.1,)
# 2024-10-17 12:43:31,202 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:31,204 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:31,206 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:31,207 INFO sqlalchemy.engine.Engine [cached since 0.437s ago] (6265,)
# 2024-10-17 12:43:31,210 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:31,210 INFO sqlalchemy.engine.Engine [cached since 0.446s ago] (144959.1,)
# 2024-10-17 12:43:31,212 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:31,215 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:31,215 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:31,216 INFO sqlalchemy.engine.Engine [cached since 0.4457s ago] (6266,)
# 2024-10-17 12:43:31,218 INFO sqlalchemy.engine.Engine INSERT INTO feature (med_income, house_age, ave_rooms, ave_bedrooms, ave_occupancy) VALUES (?, ?, ?, ?, ?)
# 2024-10-17 12:43:31,218 INFO sqlalchemy.engine.Engine [cached since 0.4628s ago] (3.5348, 3.0, 3.0, 3.0, 3.6)
# 2024-10-17 12:43:31,220 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:31,222 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:31,224 INFO sqlalchemy.engine.Engine SELECT feature.feature_id AS feature_feature_id, feature.med_income AS feature_med_income, feature.house_age AS feature_house_age, feature.ave_rooms AS feature_ave_rooms, feature.ave_bedrooms AS feature_ave_bedrooms, feature.ave_occupancy AS feature_ave_occupancy
# FROM feature
# WHERE feature.feature_id = ?
# 2024-10-17 12:43:31,225 INFO sqlalchemy.engine.Engine [cached since 0.463s ago] (17033,)
# 2024-10-17 12:43:31,226 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:31,227 INFO sqlalchemy.engine.Engine [cached since 0.4629s ago] (122080.0,)
# 2024-10-17 12:43:31,228 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:31,231 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:31,232 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:31,232 INFO sqlalchemy.engine.Engine [cached since 0.4621s ago] (6267,)
# 2024-10-17 12:43:31,234 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:31,235 INFO sqlalchemy.engine.Engine [cached since 0.4704s ago] (166770.0,)
# 2024-10-17 12:43:31,236 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:31,238 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:31,239 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:31,239 INFO sqlalchemy.engine.Engine [cached since 0.4691s ago] (6268,)
# 2024-10-17 12:43:31,241 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:31,241 INFO sqlalchemy.engine.Engine [cached since 0.4768s ago] (190750.0,)
# 2024-10-17 12:43:31,242 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:31,245 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:31,246 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:31,247 INFO sqlalchemy.engine.Engine [cached since 0.4765s ago] (6269,)
# 2024-10-17 12:43:31,250 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:31,251 INFO sqlalchemy.engine.Engine [cached since 0.4864s ago] (47415.0,)
# 2024-10-17 12:43:31,252 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:31,254 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:31,254 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:31,255 INFO sqlalchemy.engine.Engine [cached since 0.4846s ago] (6270,)
# 2024-10-17 12:43:31,257 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:31,257 INFO sqlalchemy.engine.Engine [cached since 0.4931s ago] (43491.0,)
# 2024-10-17 12:43:31,259 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:31,261 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:31,262 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:31,263 INFO sqlalchemy.engine.Engine [cached since 0.4925s ago] (6271,)
# 2024-10-17 12:43:31,265 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:31,266 INFO sqlalchemy.engine.Engine [cached since 0.5018s ago] (68670.0,)
# 2024-10-17 12:43:31,267 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:31,269 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:31,270 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:31,271 INFO sqlalchemy.engine.Engine [cached since 0.5003s ago] (6272,)
# 2024-10-17 12:43:31,272 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:31,273 INFO sqlalchemy.engine.Engine [cached since 0.5083s ago] (114341.0,)
# 2024-10-17 12:43:31,274 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:31,276 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:31,276 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:31,277 INFO sqlalchemy.engine.Engine [cached since 0.5066s ago] (6273,)
# 2024-10-17 12:43:31,279 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:31,280 INFO sqlalchemy.engine.Engine [cached since 0.5154s ago] (144861.0,)
# 2024-10-17 12:43:31,281 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:31,283 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:31,284 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:31,284 INFO sqlalchemy.engine.Engine [cached since 0.5142s ago] (6274,)
# 2024-10-17 12:43:31,286 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:31,286 INFO sqlalchemy.engine.Engine [cached since 0.522s ago] (107910.0,)
# 2024-10-17 12:43:31,287 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:31,289 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:31,290 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:31,290 INFO sqlalchemy.engine.Engine [cached since 0.5202s ago] (6275,)
# 2024-10-17 12:43:31,292 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:31,292 INFO sqlalchemy.engine.Engine [cached since 0.528s ago] (103441.0,)
# 2024-10-17 12:43:31,293 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:31,296 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:31,296 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:31,297 INFO sqlalchemy.engine.Engine [cached since 0.5263s ago] (6276,)
# 2024-10-17 12:43:31,298 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:31,298 INFO sqlalchemy.engine.Engine [cached since 0.534s ago] (150311.0,)
# 2024-10-17 12:43:31,299 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:31,303 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:31,303 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:31,304 INFO sqlalchemy.engine.Engine [cached since 0.5336s ago] (6277,)
# 2024-10-17 12:43:31,305 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:31,306 INFO sqlalchemy.engine.Engine [cached since 0.5418s ago] (136250.0,)
# 2024-10-17 12:43:31,307 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:31,310 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:31,311 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:31,313 INFO sqlalchemy.engine.Engine [cached since 0.5424s ago] (6278,)
# 2024-10-17 12:43:31,315 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:31,316 INFO sqlalchemy.engine.Engine [cached since 0.5519s ago] (144970.0,)
# 2024-10-17 12:43:31,317 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:31,320 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:31,322 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:31,323 INFO sqlalchemy.engine.Engine [cached since 0.5527s ago] (6279,)
# 2024-10-17 12:43:31,325 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:31,325 INFO sqlalchemy.engine.Engine [cached since 0.561s ago] (118265.0,)
# 2024-10-17 12:43:31,326 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:31,328 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:31,329 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:31,330 INFO sqlalchemy.engine.Engine [cached since 0.5595s ago] (6280,)
# 2024-10-17 12:43:31,331 INFO sqlalchemy.engine.Engine INSERT INTO feature (med_income, house_age, ave_rooms, ave_bedrooms, ave_occupancy) VALUES (?, ?, ?, ?, ?)
# 2024-10-17 12:43:31,332 INFO sqlalchemy.engine.Engine [cached since 0.5763s ago] (2.5634, 1.0, 1.0, 1.0, 1.2)
# 2024-10-17 12:43:31,333 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:31,335 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:31,335 INFO sqlalchemy.engine.Engine SELECT feature.feature_id AS feature_feature_id, feature.med_income AS feature_med_income, feature.house_age AS feature_house_age, feature.ave_rooms AS feature_ave_rooms, feature.ave_bedrooms AS feature_ave_bedrooms, feature.ave_occupancy AS feature_ave_occupancy
# FROM feature
# WHERE feature.feature_id = ?
# 2024-10-17 12:43:31,336 INFO sqlalchemy.engine.Engine [cached since 0.5741s ago] (17034,)
# 2024-10-17 12:43:31,337 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:31,338 INFO sqlalchemy.engine.Engine [cached since 0.5733s ago] (81205.0,)
# 2024-10-17 12:43:31,339 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:31,341 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:31,341 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:31,342 INFO sqlalchemy.engine.Engine [cached since 0.5715s ago] (6281,)
# 2024-10-17 12:43:31,344 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:31,345 INFO sqlalchemy.engine.Engine [cached since 0.5811s ago] (119900.0,)
# 2024-10-17 12:43:31,347 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:31,349 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:31,350 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:31,350 INFO sqlalchemy.engine.Engine [cached since 0.5796s ago] (6282,)
# 2024-10-17 12:43:31,351 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:31,352 INFO sqlalchemy.engine.Engine [cached since 0.5874s ago] (78480.0,)
# 2024-10-17 12:43:31,353 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:31,355 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:31,357 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:31,358 INFO sqlalchemy.engine.Engine [cached since 0.5877s ago] (6283,)
# 2024-10-17 12:43:31,360 INFO sqlalchemy.engine.Engine INSERT INTO feature (med_income, house_age, ave_rooms, ave_bedrooms, ave_occupancy) VALUES (?, ?, ?, ?, ?)
# 2024-10-17 12:43:31,360 INFO sqlalchemy.engine.Engine [cached since 0.6047s ago] (3.5348, 1.0, 2.0, 2.0, 2.4)
# 2024-10-17 12:43:31,362 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:31,367 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:31,368 INFO sqlalchemy.engine.Engine SELECT feature.feature_id AS feature_feature_id, feature.med_income AS feature_med_income, feature.house_age AS feature_house_age, feature.ave_rooms AS feature_ave_rooms, feature.ave_bedrooms AS feature_ave_bedrooms, feature.ave_occupancy AS feature_ave_occupancy
# FROM feature
# WHERE feature.feature_id = ?
# 2024-10-17 12:43:31,369 INFO sqlalchemy.engine.Engine [cached since 0.607s ago] (17035,)
# 2024-10-17 12:43:31,372 INFO sqlalchemy.engine.Engine INSERT INTO price (price) VALUES (?)
# 2024-10-17 12:43:31,373 INFO sqlalchemy.engine.Engine [cached since 0.6083s ago] (97010.0,)
# 2024-10-17 12:43:31,374 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:43:31,375 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:43:31,376 INFO sqlalchemy.engine.Engine SELECT price.price_id AS price_price_id, price.price AS price_price
# FROM price
# WHERE price.price_id = ?
# 2024-10-17 12:43:31,376 INFO sqlalchemy.engine.Engine [cached since 0.6062s ago] (6284,)
# ...
# FROM feature
# WHERE feature.feature_id = ?
# 2024-10-17 12:45:53,155 INFO sqlalchemy.engine.Engine [cached since 142.4s ago] (30550,)
# 2024-10-17 12:45:53,157 INFO sqlalchemy.engine.Engine INSERT INTO feature (med_income, house_age, ave_rooms, ave_bedrooms, ave_occupancy) VALUES (?, ?, ?, ?, ?)
# 2024-10-17 12:45:53,157 INFO sqlalchemy.engine.Engine [cached since 142.4s ago] (4.6563, 16.0, 6.093457943925234, 0.9364485981308412, 3.68785046728972)
# 2024-10-17 12:45:53,159 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:45:53,162 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:45:53,163 INFO sqlalchemy.engine.Engine SELECT feature.feature_id AS feature_feature_id, feature.med_income AS feature_med_income, feature.house_age AS feature_house_age, feature.ave_rooms AS feature_ave_rooms, feature.ave_bedrooms AS feature_ave_bedrooms, feature.ave_occupancy AS feature_ave_occupancy
# FROM feature
# WHERE feature.feature_id = ?
# 2024-10-17 12:45:53,163 INFO sqlalchemy.engine.Engine [cached since 142.4s ago] (30551,)
# 2024-10-17 12:45:53,166 INFO sqlalchemy.engine.Engine INSERT INTO feature (med_income, house_age, ave_rooms, ave_bedrooms, ave_occupancy) VALUES (?, ?, ?, ?, ?)
# 2024-10-17 12:45:53,166 INFO sqlalchemy.engine.Engine [cached since 142.4s ago] (4.7872, 16.0, 5.845505617977528, 0.9775280898876404, 3.741573033707865)
# 2024-10-17 12:45:53,168 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:45:53,171 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:45:53,172 INFO sqlalchemy.engine.Engine SELECT feature.feature_id AS feature_feature_id, feature.med_income AS feature_med_income, feature.house_age AS feature_house_age, feature.ave_rooms AS feature_ave_rooms, feature.ave_bedrooms AS feature_ave_bedrooms, feature.ave_occupancy AS feature_ave_occupancy
# FROM feature
# WHERE feature.feature_id = ?
# 2024-10-17 12:45:53,173 INFO sqlalchemy.engine.Engine [cached since 142.4s ago] (30552,)
# 2024-10-17 12:45:53,174 INFO sqlalchemy.engine.Engine INSERT INTO feature (med_income, house_age, ave_rooms, ave_bedrooms, ave_occupancy) VALUES (?, ?, ?, ?, ?)
# 2024-10-17 12:45:53,175 INFO sqlalchemy.engine.Engine [cached since 142.4s ago] (3.6467, 14.0, 5.174168297455969, 1.0273972602739727, 3.954990215264188)
# 2024-10-17 12:45:53,176 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:45:53,179 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:45:53,179 INFO sqlalchemy.engine.Engine SELECT feature.feature_id AS feature_feature_id, feature.med_income AS feature_med_income, feature.house_age AS feature_house_age, feature.ave_rooms AS feature_ave_rooms, feature.ave_bedrooms AS feature_ave_bedrooms, feature.ave_occupancy AS feature_ave_occupancy
# FROM feature
# WHERE feature.feature_id = ?
# 2024-10-17 12:45:53,180 INFO sqlalchemy.engine.Engine [cached since 142.4s ago] (30553,)
# 2024-10-17 12:45:53,181 INFO sqlalchemy.engine.Engine INSERT INTO feature (med_income, house_age, ave_rooms, ave_bedrooms, ave_occupancy) VALUES (?, ?, ?, ?, ?)
# 2024-10-17 12:45:53,182 INFO sqlalchemy.engine.Engine [cached since 142.4s ago] (3.9336, 15.0, 5.553191489361702, 1.0687397708674304, 3.337152209492635)
# 2024-10-17 12:45:53,183 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:45:53,185 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:45:53,185 INFO sqlalchemy.engine.Engine SELECT feature.feature_id AS feature_feature_id, feature.med_income AS feature_med_income, feature.house_age AS feature_house_age, feature.ave_rooms AS feature_ave_rooms, feature.ave_bedrooms AS feature_ave_bedrooms, feature.ave_occupancy AS feature_ave_occupancy
# FROM feature
# WHERE feature.feature_id = ?
# 2024-10-17 12:45:53,186 INFO sqlalchemy.engine.Engine [cached since 142.4s ago] (30554,)
# 2024-10-17 12:45:53,187 INFO sqlalchemy.engine.Engine INSERT INTO feature (med_income, house_age, ave_rooms, ave_bedrooms, ave_occupancy) VALUES (?, ?, ?, ?, ?)
# 2024-10-17 12:45:53,188 INFO sqlalchemy.engine.Engine [cached since 142.4s ago] (4.2054, 10.0, 5.515837104072398, 1.048265460030166, 3.1357466063348416)
# 2024-10-17 12:45:53,190 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:45:53,192 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:45:53,194 INFO sqlalchemy.engine.Engine SELECT feature.feature_id AS feature_feature_id, feature.med_income AS feature_med_income, feature.house_age AS feature_house_age, feature.ave_rooms AS feature_ave_rooms, feature.ave_bedrooms AS feature_ave_bedrooms, feature.ave_occupancy AS feature_ave_occupancy
# FROM feature
# WHERE feature.feature_id = ?
# 2024-10-17 12:45:53,195 INFO sqlalchemy.engine.Engine [cached since 142.4s ago] (30555,)
# 2024-10-17 12:45:53,198 INFO sqlalchemy.engine.Engine INSERT INTO feature (med_income, house_age, ave_rooms, ave_bedrooms, ave_occupancy) VALUES (?, ?, ?, ?, ?)
# 2024-10-17 12:45:53,198 INFO sqlalchemy.engine.Engine [cached since 142.4s ago] (3.2062, 6.0, 4.809847198641766, 1.066213921901528, 2.9151103565365024)
# 2024-10-17 12:45:53,200 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:45:53,202 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:45:53,203 INFO sqlalchemy.engine.Engine SELECT feature.feature_id AS feature_feature_id, feature.med_income AS feature_med_income, feature.house_age AS feature_house_age, feature.ave_rooms AS feature_ave_rooms, feature.ave_bedrooms AS feature_ave_bedrooms, feature.ave_occupancy AS feature_ave_occupancy
# FROM feature
# WHERE feature.feature_id = ?
# 2024-10-17 12:45:53,204 INFO sqlalchemy.engine.Engine [cached since 142.4s ago] (30556,)
# 2024-10-17 12:45:53,205 INFO sqlalchemy.engine.Engine INSERT INTO feature (med_income, house_age, ave_rooms, ave_bedrooms, ave_occupancy) VALUES (?, ?, ?, ?, ?)
# 2024-10-17 12:45:53,206 INFO sqlalchemy.engine.Engine [cached since 142.4s ago] (5.2551, 13.0, 6.071428571428571, 0.9894179894179894, 3.3968253968253967)
# 2024-10-17 12:45:53,207 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:45:53,209 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:45:53,211 INFO sqlalchemy.engine.Engine SELECT feature.feature_id AS feature_feature_id, feature.med_income AS feature_med_income, feature.house_age AS feature_house_age, feature.ave_rooms AS feature_ave_rooms, feature.ave_bedrooms AS feature_ave_bedrooms, feature.ave_occupancy AS feature_ave_occupancy
# FROM feature
# WHERE feature.feature_id = ?
# 2024-10-17 12:45:53,212 INFO sqlalchemy.engine.Engine [cached since 142.4s ago] (30557,)
# 2024-10-17 12:45:53,214 INFO sqlalchemy.engine.Engine INSERT INTO feature (med_income, house_age, ave_rooms, ave_bedrooms, ave_occupancy) VALUES (?, ?, ?, ?, ?)
# 2024-10-17 12:45:53,218 INFO sqlalchemy.engine.Engine [cached since 142.5s ago] (3.0598, 13.0, 4.310055865921788, 1.0698324022346368, 2.1675977653631286)
# 2024-10-17 12:45:53,220 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:45:53,223 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:45:53,223 INFO sqlalchemy.engine.Engine SELECT feature.feature_id AS feature_feature_id, feature.med_income AS feature_med_income, feature.house_age AS feature_house_age, feature.ave_rooms AS feature_ave_rooms, feature.ave_bedrooms AS feature_ave_bedrooms, feature.ave_occupancy AS feature_ave_occupancy
# FROM feature
# WHERE feature.feature_id = ?
# 2024-10-17 12:45:53,224 INFO sqlalchemy.engine.Engine [cached since 142.5s ago] (30558,)
# 2024-10-17 12:45:53,225 INFO sqlalchemy.engine.Engine INSERT INTO feature (med_income, house_age, ave_rooms, ave_bedrooms, ave_occupancy) VALUES (?, ?, ?, ?, ?)
# 2024-10-17 12:45:53,226 INFO sqlalchemy.engine.Engine [cached since 142.5s ago] (3.9107, 27.0, 5.572815533980583, 1.0, 3.116504854368932)
# 2024-10-17 12:45:53,226 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:45:53,229 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:45:53,229 INFO sqlalchemy.engine.Engine SELECT feature.feature_id AS feature_feature_id, feature.med_income AS feature_med_income, feature.house_age AS feature_house_age, feature.ave_rooms AS feature_ave_rooms, feature.ave_bedrooms AS feature_ave_bedrooms, feature.ave_occupancy AS feature_ave_occupancy
# FROM feature
# WHERE feature.feature_id = ?
# 2024-10-17 12:45:53,230 INFO sqlalchemy.engine.Engine [cached since 142.5s ago] (30559,)
# 2024-10-17 12:45:53,231 INFO sqlalchemy.engine.Engine INSERT INTO feature (med_income, house_age, ave_rooms, ave_bedrooms, ave_occupancy) VALUES (?, ?, ?, ?, ?)
# 2024-10-17 12:45:53,232 INFO sqlalchemy.engine.Engine [cached since 142.5s ago] (4.4042, 9.0, 5.416452442159383, 1.056555269922879, 2.9254498714652954)
# 2024-10-17 12:45:53,233 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:45:53,235 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:45:53,236 INFO sqlalchemy.engine.Engine SELECT feature.feature_id AS feature_feature_id, feature.med_income AS feature_med_income, feature.house_age AS feature_house_age, feature.ave_rooms AS feature_ave_rooms, feature.ave_bedrooms AS feature_ave_bedrooms, feature.ave_occupancy AS feature_ave_occupancy
# FROM feature
# WHERE feature.feature_id = ?
# 2024-10-17 12:45:53,236 INFO sqlalchemy.engine.Engine [cached since 142.5s ago] (30560,)
# 2024-10-17 12:45:53,238 INFO sqlalchemy.engine.Engine INSERT INTO feature (med_income, house_age, ave_rooms, ave_bedrooms, ave_occupancy) VALUES (?, ?, ?, ?, ?)
# 2024-10-17 12:45:53,238 INFO sqlalchemy.engine.Engine [cached since 142.5s ago] (5.753, 14.0, 6.071022727272728, 0.9801136363636364, 3.269886363636364)
# 2024-10-17 12:45:53,239 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:45:53,241 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:45:53,242 INFO sqlalchemy.engine.Engine SELECT feature.feature_id AS feature_feature_id, feature.med_income AS feature_med_income, feature.house_age AS feature_house_age, feature.ave_rooms AS feature_ave_rooms, feature.ave_bedrooms AS feature_ave_bedrooms, feature.ave_occupancy AS feature_ave_occupancy
# FROM feature
# WHERE feature.feature_id = ?
# 2024-10-17 12:45:53,242 INFO sqlalchemy.engine.Engine [cached since 142.5s ago] (30561,)
# 2024-10-17 12:45:53,244 INFO sqlalchemy.engine.Engine INSERT INTO feature (med_income, house_age, ave_rooms, ave_bedrooms, ave_occupancy) VALUES (?, ?, ?, ?, ?)
# 2024-10-17 12:45:53,245 INFO sqlalchemy.engine.Engine [cached since 142.5s ago] (4.8906, 16.0, 6.404210526315789, 1.103157894736842, 3.191578947368421)
# 2024-10-17 12:45:53,246 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:45:53,248 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:45:53,248 INFO sqlalchemy.engine.Engine SELECT feature.feature_id AS feature_feature_id, feature.med_income AS feature_med_income, feature.house_age AS feature_house_age, feature.ave_rooms AS feature_ave_rooms, feature.ave_bedrooms AS feature_ave_bedrooms, feature.ave_occupancy AS feature_ave_occupancy
# FROM feature
# WHERE feature.feature_id = ?
# 2024-10-17 12:45:53,249 INFO sqlalchemy.engine.Engine [cached since 142.5s ago] (30562,)
# 2024-10-17 12:45:53,250 INFO sqlalchemy.engine.Engine INSERT INTO feature (med_income, house_age, ave_rooms, ave_bedrooms, ave_occupancy) VALUES (?, ?, ?, ?, ?)
# 2024-10-17 12:45:53,250 INFO sqlalchemy.engine.Engine [cached since 142.5s ago] (6.7544, 11.0, 6.966804979253112, 1.045643153526971, 3.506224066390041)
# 2024-10-17 12:45:53,251 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:45:53,254 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:45:53,255 INFO sqlalchemy.engine.Engine SELECT feature.feature_id AS feature_feature_id, feature.med_income AS feature_med_income, feature.house_age AS feature_house_age, feature.ave_rooms AS feature_ave_rooms, feature.ave_bedrooms AS feature_ave_bedrooms, feature.ave_occupancy AS feature_ave_occupancy
# FROM feature
# WHERE feature.feature_id = ?
# 2024-10-17 12:45:53,255 INFO sqlalchemy.engine.Engine [cached since 142.5s ago] (30563,)
# 2024-10-17 12:45:53,257 INFO sqlalchemy.engine.Engine INSERT INTO feature (med_income, house_age, ave_rooms, ave_bedrooms, ave_occupancy) VALUES (?, ?, ?, ?, ?)
# 2024-10-17 12:45:53,258 INFO sqlalchemy.engine.Engine [cached since 142.5s ago] (3.449, 15.0, 5.151515151515151, 1.0524475524475525, 2.765734265734266)
# 2024-10-17 12:45:53,259 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:45:53,262 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:45:53,263 INFO sqlalchemy.engine.Engine SELECT feature.feature_id AS feature_feature_id, feature.med_income AS feature_med_income, feature.house_age AS feature_house_age, feature.ave_rooms AS feature_ave_rooms, feature.ave_bedrooms AS feature_ave_bedrooms, feature.ave_occupancy AS feature_ave_occupancy
# FROM feature
# WHERE feature.feature_id = ?
# 2024-10-17 12:45:53,264 INFO sqlalchemy.engine.Engine [cached since 142.5s ago] (30564,)
# 2024-10-17 12:45:53,266 INFO sqlalchemy.engine.Engine INSERT INTO feature (med_income, house_age, ave_rooms, ave_bedrooms, ave_occupancy) VALUES (?, ?, ?, ?, ?)
# 2024-10-17 12:45:53,267 INFO sqlalchemy.engine.Engine [cached since 142.5s ago] (2.5048, 28.0, 3.9864864864864864, 1.025337837837838, 4.430743243243243)
# 2024-10-17 12:45:53,269 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:45:53,271 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:45:53,272 INFO sqlalchemy.engine.Engine SELECT feature.feature_id AS feature_feature_id, feature.med_income AS feature_med_income, feature.house_age AS feature_house_age, feature.ave_rooms AS feature_ave_rooms, feature.ave_bedrooms AS feature_ave_bedrooms, feature.ave_occupancy AS feature_ave_occupancy
# FROM feature
# WHERE feature.feature_id = ?
# 2024-10-17 12:45:53,272 INFO sqlalchemy.engine.Engine [cached since 142.5s ago] (30565,)
# 2024-10-17 12:45:53,274 INFO sqlalchemy.engine.Engine INSERT INTO feature (med_income, house_age, ave_rooms, ave_bedrooms, ave_occupancy) VALUES (?, ?, ?, ?, ?)
# 2024-10-17 12:45:53,275 INFO sqlalchemy.engine.Engine [cached since 142.5s ago] (3.0057, 32.0, 4.212686567164179, 0.9365671641791044, 5.141791044776119)
# 2024-10-17 12:45:53,276 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:45:53,278 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:45:53,279 INFO sqlalchemy.engine.Engine SELECT feature.feature_id AS feature_feature_id, feature.med_income AS feature_med_income, feature.house_age AS feature_house_age, feature.ave_rooms AS feature_ave_rooms, feature.ave_bedrooms AS feature_ave_bedrooms, feature.ave_occupancy AS feature_ave_occupancy
# FROM feature
# WHERE feature.feature_id = ?
# 2024-10-17 12:45:53,279 INFO sqlalchemy.engine.Engine [cached since 142.5s ago] (30566,)
# 2024-10-17 12:45:53,280 INFO sqlalchemy.engine.Engine INSERT INTO feature (med_income, house_age, ave_rooms, ave_bedrooms, ave_occupancy) VALUES (?, ?, ?, ?, ?)
# 2024-10-17 12:45:53,281 INFO sqlalchemy.engine.Engine [cached since 142.5s ago] (2.1944, 27.0, 4.02, 1.0342857142857145, 4.811428571428571)
# 2024-10-17 12:45:53,282 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:45:53,284 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-17 12:45:53,400 INFO sqlalchemy.engine.Engine SELECT feature.feature_id AS feature_feature_id, feature.med_income AS feature_med_income, feature.house_age AS feature_house_age, feature.ave_rooms AS feature_ave_rooms, feature.ave_bedrooms AS feature_ave_bedrooms, feature.ave_occupancy AS feature_ave_occupancy
# FROM feature
# WHERE feature.feature_id = ?
# 2024-10-17 12:45:53,402 INFO sqlalchemy.engine.Engine [cached since 142.6s ago] (30567,)
# 2024-10-17 12:45:53,404 INFO sqlalchemy.engine.Engine INSERT INTO feature (med_income, house_age, ave_rooms, ave_bedrooms, ave_occupancy) VALUES (?, ?, ?, ?, ?)
# 2024-10-17 12:45:53,406 INFO sqlalchemy.engine.Engine [cached since 142.6s ago] (4.8281, 11.0, 5.525606469002695, 1.0296495956873315, 2.8140161725067387)
# 2024-10-17 12:45:53,407 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-17 12:45:53,410 INFO sqlalchemy.engine.Engine BEGIN (implicit)
